# %% [markdown]
# **Daemon Threads**
#
# * **Definition:** Threads that run in the background to support other threads (like the main thread) are called Daemon Threads.
# * **Purpose:** Provide support to non-daemon threads.
# * **Example:** Garbage Collector.
# * **Checking Daemon Status:** Use `t.daemon` property.

# %% [markdown]
# ### **Daemon Threads in Python**
#
# **Daemon Threads** are threads that run in the background. Their main purpose is to provide support for non-daemon threads (like the main thread).
#
# - **Daemon threads terminate automatically** when all non-daemon threads finish execution.
# - **Non-daemon threads** are essential for the program and continue running until they complete execution.
# - Common use cases: Background tasks such as logging, monitoring, or garbage collection.
#
#
# #### Checking Daemon Status
# In Python 3.10 and later, the `isDaemon()` method is deprecated. Use the `daemon` property instead.
#
# ```python
# from threading import current_thread
#
# # Check if the current thread is a daemon thread
# print(current_thread().daemon)  # Output: False
# ```
#
#
# #### Setting Daemon Status
# To set a thread as a daemon, use the `daemon` property before starting the thread.
# **Note**: Once a thread has started, you cannot change its daemon status.
#
# ```python
# from threading import Thread
#
# def worker():
#     print("Child thread is running")
#
# # Create a thread
# t = Thread(target=worker)
#
# # Set the thread as daemon
# t.daemon = True
# print(t.daemon)  # Output: True
#
# # Start the thread
# t.start()
# ```
#
# #### Attempting to Change Daemon Status After Starting:
# ```python
# from threading import Thread
#
# t = Thread(target=lambda: print("Hello"))
# t.start()
#
# # Attempting to change daemon status after starting raises an error
# t.daemon = True  # Raises RuntimeError: cannot set daemon status of active thread
# ```
#
#
# #### Default Daemon Nature
# 1. **Main Thread**: Always non-daemon and cannot have its status changed.
# 2. **Child Threads**: Inherit daemon status from their parent thread:
#    - If the parent thread is non-daemon, the child thread is non-daemon.
#    - If the parent thread is daemon, the child thread is also daemon.
#
# ```python
# from threading import Thread
#
# def worker():
#     print("Child thread running")
#
# # Create a child thread
# t = Thread(target=worker)
#
# # Default daemon status is inherited from the parent (main thread)
# print(t.daemon)  # Output: False
#
# # Set the child thread as daemon
# t.daemon = True
# print(t.daemon)  # Output: True
# ```
#
# #### Daemon Thread Termination
# When the last non-daemon thread terminates, all daemon threads are automatically terminated, even if they are still executing.
#
# ```python
# from threading import Thread
# import time
#
# def worker():
#     for i in range(10):
#         print("Lazy thread")
#         time.sleep(2)
#
# t = Thread(target=worker)
#
# # Uncomment to make the thread a daemon
# # t.daemon = True
#
# t.start()
# time.sleep(5)
# print("End of main thread")
# ```
#
# - **If the child thread is non-daemon**:
#   The program will wait for the child thread to finish.
#   ```
#   Lazy thread
#   Lazy thread
#   Lazy thread
#   End of main thread
#   Lazy thread
#   ...
#   ```
#
# - **If the child thread is daemon**:
#   The child thread will terminate when the main thread finishes.
#   ```
#   Lazy thread
#   Lazy thread
#   Lazy thread
#   End of main thread
#   ```
#
# #### Summary
# 1. Use `daemon` property to check or set daemon status.
# 2. Always set daemon status **before starting the thread**.
# 3. The main thread is always non-daemon and cannot be changed.
# 4. Daemon threads terminate automatically when all non-daemon threads finish.

# %%
import threading

def worker():
    print("Worker thread is running")
    
t = threading.Thread(target=worker)
print(f"Is thread a daemon? {t.daemon}") 
t.daemon = True
print(f"Is thread a daemon after setting? {t.daemon}")
# Out:
# Is thread a daemon? False
# Is thread a daemon after setting? True

# %% [markdown]
# - **`daemon`**: Returns `True` if the thread is a daemon thread and can be accessed directly to check or set the thread's daemon status.
#
# **Notes**
# 1. **Daemon Threads**:
#    - A daemon thread runs in the background and is automatically killed when the main thread exits.
#    - Used for tasks like background monitoring, cleanup, or similar operations.
#
# 2. **Non-Daemon Threads**:
#    - A non-daemon thread keeps the program running until it finishes executing, even if the main thread exits.
#
# 3. **Default Behavior**:
#    - A thread is **non-daemon** by default unless explicitly set as a daemon (`t.daemon = True`) before calling `t.start()`.

# %%
# import threading
# import time

# def background_task():
#     while True:
#         print("Background task is running...")
#         time.sleep(2)

# def main_task():
#     for i in range(5):
#         print(f"Main task iteration {i+1}")
#         time.sleep(1)

# # Create a non-daemon thread for the background task
# background_thread = threading.Thread(target=background_task)
# background_thread.daemon = False  # Ensure the thread is non-daemon
# background_thread.start()

# # Run the main task
# main_task()

# print("Main task completed. Waiting for background task to complete.")
# background_thread.join()  # Wait for the background thread to complete
# print("Background task completed. Exiting program.")
# Out:
# Background task is running...
# Main task iteration 1
# Main task iteration 2
# Background task is running...
# Main task iteration 3
# Main task iteration 4
# Background task is running...
# Main task iteration 5
# Main task completed. Waiting for background task to complete.
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...

# %%
import threading
import time
import logging

# Configure logging to display thread name and message
logging.basicConfig(level=logging.DEBUG, format='%(threadName)s: %(message)s')

def monitor_system():
    """Background task to monitor system status."""
    while True:
        logging.debug('Monitoring system health...')
        time.sleep(5)

def main_task():
    """Main task representing the primary application logic."""
    for i in range(3):
        logging.debug(f'Executing main task iteration {i+1}')
        time.sleep(2)
    logging.debug('Main task completed.')

if __name__ == "__main__":
    # Create and start the daemon thread for system monitoring
    monitor_thread = threading.Thread(target=monitor_system, name='MonitorThread')
    monitor_thread.daemon = True
    monitor_thread.start()

    # Execute the main task
    main_task()

    logging.debug('Program exiting. Daemon thread will be terminated.')
# Out:
# MonitorThread: Monitoring system health...
# MainThread: Executing main task iteration 1
# MainThread: Executing main task iteration 2
# MainThread: Executing main task iteration 3
# MonitorThread: Monitoring system health...
# MainThread: Main task completed.
# MainThread: Program exiting. Daemon thread will be terminated.
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...
# MonitorThread: Monitoring system health...

# %%
import threading
import time

def background_task():
    with open('log.txt', 'a') as file:
        while True:
            file.write('Logging data...\n')
            time.sleep(2)

# Create a daemon thread
daemon_thread = threading.Thread(target=background_task)
daemon_thread.daemon = True
daemon_thread.start()

# Main task
time.sleep(5)
print("Main task completed.")
# Out:
# Main task completed.

# %%
import threading
import time

def background_task():
    with open('log.txt', 'a') as file:
        while True:
            file.write('Logging data...\n')
            time.sleep(2)

# Create a daemon thread
daemon_thread = threading.Thread(target=background_task)
daemon_thread.daemon = True
daemon_thread.start()

# Main task
time.sleep(5)
print("Main task completed.")
# Out:
# Main task completed.

# %%
import threading
import time

def background_task():
    while True:
        raise Exception("An error occurred in the background task.")
        time.sleep(2)

# Create a daemon thread
daemon_thread = threading.Thread(target=background_task)
daemon_thread.daemon = True
daemon_thread.start()

# Main task
time.sleep(5)
print("Main task completed.")
# Out:
# Exception in thread Thread-5 (background_task):
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_1476\3108262762.py", line 6, in background_task
# Exception: An error occurred in the background task.
# Main task completed.

# %%
import threading
import time
import atexit

def background_task():
    while True:
        time.sleep(2)

def cleanup():
    print("Performing cleanup tasks.")

atexit.register(cleanup)

# Create a daemon thread
daemon_thread = threading.Thread(target=background_task)
daemon_thread.daemon = True
daemon_thread.start()

# Main task
time.sleep(5)
print("Main task completed.")
# Out:
# Main task completed.

# %%
import threading
import time
import signal

def background_task():
    while True:
        print("Background task is running...")
        time.sleep(2)

def handle_signal(signum, frame):
    print(f"Signal {signum} received.")

signal.signal(signal.SIGINT, handle_signal)

# Create a daemon thread
daemon_thread = threading.Thread(target=background_task)
daemon_thread.daemon = True
daemon_thread.start()

# Main task
time.sleep(5)
print("Main task completed.")
# Out:
# Background task is running...
# Background task is running...
# Background task is running...
# Main task completed.
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...

# %%
import concurrent.futures
import time

def background_task():
    while True:
        print("Background task is running...")
        time.sleep(2)

# Create a ThreadPoolExecutor
with concurrent.futures.ThreadPoolExecutor(max_workers=1) as executor:
    future = executor.submit(background_task)
    time.sleep(5)
    print("Main task completed.")
# Out:
# Background task is running...
# Background task is running...
# Background task is running...
# Main task completed.
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...
# Background task is running...

# %%
import threading
import time
import logging
from queue import Queue

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(threadName)s - %(message)s'
)

# Example 1: Basic Daemon Thread
def basic_daemon_example():
    def background_task():
        while True:
            logging.info("Background task running...")
            time.sleep(2)
    
    daemon_thread = threading.Thread(
        target=background_task,
        daemon=True,
        name="BasicDaemon"
    )
    daemon_thread.start()
    
    # Main thread works for 5 seconds
    logging.info("Main thread working...")
    time.sleep(5)
    logging.info("Main thread finished - daemon will be terminated")

# Example 2: Daemon Thread with Queue
def queue_daemon_example():
    def worker(queue):
        while True:
            try:
                item = queue.get(timeout=1)
                logging.info(f"Processing item: {item}")
                time.sleep(0.5)
                queue.task_done()
            except queue.Empty:
                continue
    
    work_queue = Queue()
    daemon_thread = threading.Thread(
        target=worker,
        args=(work_queue,),
        daemon=True,
        name="QueueDaemon"
    )
    daemon_thread.start()
    
    # Add some work to the queue
    for i in range(5):
        work_queue.put(f"Task {i}")
    
    # Wait for queue to be processed
    work_queue.join()
    logging.info("All queue items processed")

# Example 3: Multiple Daemon Threads with Event
def multiple_daemons_example():
    stop_event = threading.Event()
    
    def sensor_reader(sensor_id):
        while not stop_event.is_set():
            logging.info(f"Reading from sensor {sensor_id}")
            time.sleep(1)
    
    # Create multiple daemon threads
    sensors = []
    for i in range(3):
        thread = threading.Thread(
            target=sensor_reader,
            args=(i,),
            daemon=True,
            name=f"Sensor{i}"
        )
        sensors.append(thread)
        thread.start()
    
    # Let sensors run for a while
    time.sleep(5)
    stop_event.set()
    logging.info("Stopping all sensors")

# Example 4: Daemon Thread with Graceful Shutdown
def graceful_shutdown_example():
    shutdown_flag = threading.Event()
    
    def monitored_task():
        while not shutdown_flag.is_set():
            logging.info("Performing monitored task...")
            time.sleep(1)
        
        logging.info("Cleaning up monitored task...")
        time.sleep(2)
        logging.info("Cleanup complete")
    
    daemon_thread = threading.Thread(
        target=monitored_task,
        daemon=True,
        name="GracefulDaemon"
    )
    daemon_thread.start()
    
    # Run for a few seconds
    time.sleep(3)
    
    # Signal shutdown and wait briefly for cleanup
    logging.info("Initiating graceful shutdown")
    shutdown_flag.set()
    time.sleep(3)

if __name__ == "__main__":
    logging.info("Starting daemon thread examples\n")
    
    logging.info("=== Basic Daemon Example ===")
    basic_daemon_example()
    time.sleep(1)
    
    logging.info("\n=== Queue Daemon Example ===")
    queue_daemon_example()
    time.sleep(1)
    
    logging.info("\n=== Multiple Daemons Example ===")
    multiple_daemons_example()
    time.sleep(1)
    
    logging.info("\n=== Graceful Shutdown Example ===")
    graceful_shutdown_example()
    
    logging.info("\nAll examples completed")
# Out:
# 2025-01-08 08:49:30,356 - MainThread - Starting daemon thread examples
#
# 2025-01-08 08:49:30,357 - MainThread - === Basic Daemon Example ===
# 2025-01-08 08:49:30,366 - BasicDaemon - Background task running...
# 2025-01-08 08:49:30,368 - MainThread - Main thread working...
# 2025-01-08 08:49:32,372 - BasicDaemon - Background task running...
# 2025-01-08 08:49:34,375 - BasicDaemon - Background task running...
# 2025-01-08 08:49:35,373 - MainThread - Main thread finished - daemon will be terminated
# 2025-01-08 08:49:36,374 - MainThread -
# === Queue Daemon Example ===
# 2025-01-08 08:49:36,378 - BasicDaemon - Background task running...
# 2025-01-08 08:49:36,379 - QueueDaemon - Processing item: Task 0
# 2025-01-08 08:49:36,886 - QueueDaemon - Processing item: Task 1
# 2025-01-08 08:49:37,390 - QueueDaemon - Processing item: Task 2
# 2025-01-08 08:49:37,892 - QueueDaemon - Processing item: Task 3
# 2025-01-08 08:49:38,381 - BasicDaemon - Background task running...
# 2025-01-08 08:49:38,395 - QueueDaemon - Processing item: Task 4
# 2025-01-08 08:49:38,897 - MainThread - All queue items processed
# 2025-01-08 08:49:39,898 - MainThread -
# === Multiple Daemons Example ===
# 2025-01-08 08:49:39,900 - Sensor0 - Reading from sensor 0
# Exception in thread QueueDaemon:
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_5512\3008579710.py", line 36, in worker
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\queue.py", line 179, in get
#     raise Empty
# _queue.Empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1075, in _bootstrap_inner
# 2025-01-08 08:49:39,904 - Sensor1 - Reading from sensor 1
# 2025-01-08 08:49:39,908 - Sensor2 - Reading from sensor 2
#     self.run()
#   File "C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_5512\3008579710.py", line 40, in worker
# AttributeError: 'Queue' object has no attribute 'Empty'. Did you mean: 'empty'?
# 2025-01-08 08:49:40,383 - BasicDaemon - Background task running...
# 2025-01-08 08:49:40,911 - Sensor0 - Reading from sensor 0
# 2025-01-08 08:49:40,915 - Sensor1 - Reading from sensor 1
# 2025-01-08 08:49:40,917 - Sensor2 - Reading from sensor 2
# 2025-01-08 08:49:41,912 - Sensor0 - Reading from sensor 0
# 2025-01-08 08:49:41,916 - Sensor1 - Reading from sensor 1
# 2025-01-08 08:49:41,920 - Sensor2 - Reading from sensor 2
# 2025-01-08 08:49:42,387 - BasicDaemon - Background task running...
# 2025-01-08 08:49:42,914 - Sensor0 - Reading from sensor 0
# 2025-01-08 08:49:42,918 - Sensor1 - Reading from sensor 1
# 2025-01-08 08:49:42,922 - Sensor2 - Reading from sensor 2
# 2025-01-08 08:49:43,917 - Sensor0 - Reading from sensor 0
# 2025-01-08 08:49:43,920 - Sensor1 - Reading from sensor 1
# 2025-01-08 08:49:43,925 - Sensor2 - Reading from sensor 2
# 2025-01-08 08:49:44,391 - BasicDaemon - Background task running...
# 2025-01-08 08:49:44,910 - MainThread - Stopping all sensors
# 2025-01-08 08:49:45,913 - MainThread -
# === Graceful Shutdown Example ===
# 2025-01-08 08:49:45,917 - GracefulDaemon - Performing monitored task...
# 2025-01-08 08:49:46,391 - BasicDaemon - Background task running...
# 2025-01-08 08:49:46,924 - GracefulDaemon - Performing monitored task...
# 2025-01-08 08:49:47,926 - GracefulDaemon - Performing monitored task...
# 2025-01-08 08:49:48,395 - BasicDaemon - Background task running...
# 2025-01-08 08:49:48,923 - MainThread - Initiating graceful shutdown
# 2025-01-08 08:49:48,928 - GracefulDaemon - Cleaning up monitored task...
# 2025-01-08 08:49:50,398 - BasicDaemon - Background task running...
# 2025-01-08 08:49:50,930 - GracefulDaemon - Cleanup complete
# 2025-01-08 08:49:51,926 - MainThread -
# All examples completed
# 2025-01-08 08:49:52,399 - BasicDaemon - Background task running...
# 2025-01-08 08:49:54,414 - BasicDaemon - Background task running...
# 2025-01-08 08:49:56,416 - BasicDaemon - Background task running...
# 2025-01-08 08:49:58,419 - BasicDaemon - Background task running...
# 2025-01-08 08:50:00,421 - BasicDaemon - Background task running...
# 2025-01-08 08:50:02,424 - BasicDaemon - Background task running...
# 2025-01-08 08:50:04,426 - BasicDaemon - Background task running...
# 2025-01-08 08:50:06,435 - BasicDaemon - Background task running...
# 2025-01-08 08:50:08,437 - BasicDaemon - Background task running...
# 2025-01-08 08:50:10,440 - BasicDaemon - Background task running...
# 2025-01-08 08:50:12,443 - BasicDaemon - Background task running...
# 2025-01-08 08:50:14,446 - BasicDaemon - Background task running...
# 2025-01-08 08:50:16,448 - BasicDaemon - Background task running...
# 2025-01-08 08:50:18,450 - BasicDaemon - Background task running...
# 2025-01-08 08:50:20,451 - BasicDaemon - Background task running...
# 2025-01-08 08:50:22,454 - BasicDaemon - Background task running...
# 2025-01-08 08:50:24,457 - BasicDaemon - Background task running...
# 2025-01-08 08:50:26,461 - BasicDaemon - Background task running...
# 2025-01-08 08:50:28,463 - BasicDaemon - Background task running...
# 2025-01-08 08:50:30,465 - BasicDaemon - Background task running...
# 2025-01-08 08:50:32,469 - BasicDaemon - Background task running...
# 2025-01-08 08:50:34,473 - BasicDaemon - Background task running...
# 2025-01-08 08:50:36,475 - BasicDaemon - Background task running...
# 2025-01-08 08:50:38,477 - BasicDaemon - Background task running...
# 2025-01-08 08:50:40,481 - BasicDaemon - Background task running...
# 2025-01-08 08:50:42,482 - BasicDaemon - Background task running...
# 2025-01-08 08:50:44,485 - BasicDaemon - Background task running...
# 2025-01-08 08:50:46,487 - BasicDaemon - Background task running...
# 2025-01-08 08:50:48,490 - BasicDaemon - Background task running...
# 2025-01-08 08:50:50,492 - BasicDaemon - Background task running...
# 2025-01-08 08:50:52,496 - BasicDaemon - Background task running...
# 2025-01-08 08:50:54,498 - BasicDaemon - Background task running...
# 2025-01-08 08:50:56,500 - BasicDaemon - Background task running...
# 2025-01-08 08:50:58,502 - BasicDaemon - Background task running...
# 2025-01-08 08:51:00,509 - BasicDaemon - Background task running...
# 2025-01-08 08:51:02,512 - BasicDaemon - Background task running...
# 2025-01-08 08:51:04,513 - BasicDaemon - Background task running...
# 2025-01-08 08:51:06,515 - BasicDaemon - Background task running...
# 2025-01-08 08:51:08,517 - BasicDaemon - Background task running...
# 2025-01-08 08:51:10,520 - BasicDaemon - Background task running...
# 2025-01-08 08:51:12,522 - BasicDaemon - Background task running...
# 2025-01-08 08:51:14,525 - BasicDaemon - Background task running...
# 2025-01-08 08:51:16,527 - BasicDaemon - Background task running...
# 2025-01-08 08:51:18,532 - BasicDaemon - Background task running...
# 2025-01-08 08:51:20,535 - BasicDaemon - Background task running...
# 2025-01-08 08:51:22,546 - BasicDaemon - Background task running...
# 2025-01-08 08:51:24,548 - BasicDaemon - Background task running...
# 2025-01-08 08:51:26,549 - BasicDaemon - Background task running...
# 2025-01-08 08:51:28,554 - BasicDaemon - Background task running...
# 2025-01-08 08:51:30,557 - BasicDaemon - Background task running...
# 2025-01-08 08:51:32,559 - BasicDaemon - Background task running...
# 2025-01-08 08:51:34,562 - BasicDaemon - Background task running...
# 2025-01-08 08:51:36,563 - BasicDaemon - Background task running...
# 2025-01-08 08:51:38,568 - BasicDaemon - Background task running...
# 2025-01-08 08:51:40,570 - BasicDaemon - Background task running...
# 2025-01-08 08:51:42,572 - BasicDaemon - Background task running...
# 2025-01-08 08:51:44,574 - BasicDaemon - Background task running...
# 2025-01-08 08:51:46,577 - BasicDaemon - Background task running...
# 2025-01-08 08:51:48,580 - BasicDaemon - Background task running...
# 2025-01-08 08:51:50,584 - BasicDaemon - Background task running...
# 2025-01-08 08:51:52,586 - BasicDaemon - Background task running...
# 2025-01-08 08:51:54,589 - BasicDaemon - Background task running...
# 2025-01-08 08:51:56,593 - BasicDaemon - Background task running...
# 2025-01-08 08:51:58,595 - BasicDaemon - Background task running...
# 2025-01-08 08:52:00,597 - BasicDaemon - Background task running...
# 2025-01-08 08:52:02,600 - BasicDaemon - Background task running...
# 2025-01-08 08:52:04,604 - BasicDaemon - Background task running...
# 2025-01-08 08:52:06,607 - BasicDaemon - Background task running...
# 2025-01-08 08:52:08,610 - BasicDaemon - Background task running...
# 2025-01-08 08:52:10,612 - BasicDaemon - Background task running...
# 2025-01-08 08:52:12,614 - BasicDaemon - Background task running...
# 2025-01-08 08:52:14,616 - BasicDaemon - Background task running...
# 2025-01-08 08:52:16,619 - BasicDaemon - Background task running...
# 2025-01-08 08:52:18,620 - BasicDaemon - Background task running...
# 2025-01-08 08:52:20,622 - BasicDaemon - Background task running...
# 2025-01-08 08:52:22,623 - BasicDaemon - Background task running...
# 2025-01-08 08:52:24,625 - BasicDaemon - Background task running...
# 2025-01-08 08:52:26,628 - BasicDaemon - Background task running...
# 2025-01-08 08:52:28,632 - BasicDaemon - Background task running...
# 2025-01-08 08:52:30,634 - BasicDaemon - Background task running...
# 2025-01-08 08:52:32,637 - BasicDaemon - Background task running...
# 2025-01-08 08:52:34,639 - BasicDaemon - Background task running...
# 2025-01-08 08:52:36,643 - BasicDaemon - Background task running...
# 2025-01-08 08:52:38,646 - BasicDaemon - Background task running...
# 2025-01-08 08:52:40,651 - BasicDaemon - Background task running...
# 2025-01-08 08:52:42,653 - BasicDaemon - Background task running...
# 2025-01-08 08:52:44,657 - BasicDaemon - Background task running...
# 2025-01-08 08:52:46,659 - BasicDaemon - Background task running...
# 2025-01-08 08:52:48,662 - BasicDaemon - Background task running...
# 2025-01-08 08:52:50,665 - BasicDaemon - Background task running...
# 2025-01-08 08:52:52,667 - BasicDaemon - Background task running...
# 2025-01-08 08:52:54,670 - BasicDaemon - Background task running...
# 2025-01-08 08:52:56,673 - BasicDaemon - Background task running...
# 2025-01-08 08:52:58,675 - BasicDaemon - Background task running...
# 2025-01-08 08:53:00,678 - BasicDaemon - Background task running...
# 2025-01-08 08:53:02,681 - BasicDaemon - Background task running...
# 2025-01-08 08:53:04,684 - BasicDaemon - Background task running...
# 2025-01-08 08:53:06,687 - BasicDaemon - Background task running...
# 2025-01-08 08:53:08,690 - BasicDaemon - Background task running...
# 2025-01-08 08:53:10,694 - BasicDaemon - Background task running...
# 2025-01-08 08:53:12,696 - BasicDaemon - Background task running...
# 2025-01-08 08:53:14,699 - BasicDaemon - Background task running...
# 2025-01-08 08:53:16,701 - BasicDaemon - Background task running...
# 2025-01-08 08:53:18,703 - BasicDaemon - Background task running...
# 2025-01-08 08:53:20,706 - BasicDaemon - Background task running...
# 2025-01-08 08:53:22,708 - BasicDaemon - Background task running...
# 2025-01-08 08:53:24,710 - BasicDaemon - Background task running...
# 2025-01-08 08:53:26,715 - BasicDaemon - Background task running...
# 2025-01-08 08:53:28,717 - BasicDaemon - Background task running...
# 2025-01-08 08:53:30,720 - BasicDaemon - Background task running...
# 2025-01-08 08:53:32,722 - BasicDaemon - Background task running...
# 2025-01-08 08:53:34,725 - BasicDaemon - Background task running...
# 2025-01-08 08:53:36,728 - BasicDaemon - Background task running...
# 2025-01-08 08:53:38,731 - BasicDaemon - Background task running...
# 2025-01-08 08:53:40,734 - BasicDaemon - Background task running...
# 2025-01-08 08:53:42,735 - BasicDaemon - Background task running...
# 2025-01-08 08:53:44,739 - BasicDaemon - Background task running...
# 2025-01-08 08:53:46,742 - BasicDaemon - Background task running...
# 2025-01-08 08:53:48,746 - BasicDaemon - Background task running...
# 2025-01-08 08:53:50,749 - BasicDaemon - Background task running...
# 2025-01-08 08:53:52,761 - BasicDaemon - Background task running...
# 2025-01-08 08:53:54,764 - BasicDaemon - Background task running...
# 2025-01-08 08:53:56,769 - BasicDaemon - Background task running...
# 2025-01-08 08:53:58,772 - BasicDaemon - Background task running...
# 2025-01-08 08:54:00,775 - BasicDaemon - Background task running...
# 2025-01-08 08:54:02,780 - BasicDaemon - Background task running...
# 2025-01-08 08:54:04,783 - BasicDaemon - Background task running...
# 2025-01-08 08:54:06,788 - BasicDaemon - Background task running...
# 2025-01-08 08:54:08,790 - BasicDaemon - Background task running...
# 2025-01-08 08:54:10,793 - BasicDaemon - Background task running...
# 2025-01-08 08:54:12,796 - BasicDaemon - Background task running...
# 2025-01-08 08:54:14,799 - BasicDaemon - Background task running...
# 2025-01-08 08:54:16,805 - BasicDaemon - Background task running...
# 2025-01-08 08:54:18,809 - BasicDaemon - Background task running...
# 2025-01-08 08:54:20,811 - BasicDaemon - Background task running...
# 2025-01-08 08:54:22,815 - BasicDaemon - Background task running...
# 2025-01-08 08:54:24,817 - BasicDaemon - Background task running...
# 2025-01-08 08:54:26,819 - BasicDaemon - Background task running...
# 2025-01-08 08:54:28,822 - BasicDaemon - Background task running...
# 2025-01-08 08:54:30,827 - BasicDaemon - Background task running...
# 2025-01-08 08:54:32,832 - BasicDaemon - Background task running...
# 2025-01-08 08:54:34,834 - BasicDaemon - Background task running...
# 2025-01-08 08:54:36,837 - BasicDaemon - Background task running...
# 2025-01-08 08:54:38,840 - BasicDaemon - Background task running...
# 2025-01-08 08:54:40,845 - BasicDaemon - Background task running...
# 2025-01-08 08:54:42,848 - BasicDaemon - Background task running...
# 2025-01-08 08:54:44,850 - BasicDaemon - Background task running...
# 2025-01-08 08:54:46,853 - BasicDaemon - Background task running...
# 2025-01-08 08:54:48,856 - BasicDaemon - Background task running...
# 2025-01-08 08:54:50,859 - BasicDaemon - Background task running...
# 2025-01-08 08:54:52,862 - BasicDaemon - Background task running...
# 2025-01-08 08:54:54,865 - BasicDaemon - Background task running...
# 2025-01-08 08:54:56,868 - BasicDaemon - Background task running...
# 2025-01-08 08:54:58,870 - BasicDaemon - Background task running...
# 2025-01-08 08:55:00,874 - BasicDaemon - Background task running...
# 2025-01-08 08:55:02,876 - BasicDaemon - Background task running...
# 2025-01-08 08:55:04,878 - BasicDaemon - Background task running...
# 2025-01-08 08:55:06,880 - BasicDaemon - Background task running...
# 2025-01-08 08:55:08,883 - BasicDaemon - Background task running...
# 2025-01-08 08:55:10,885 - BasicDaemon - Background task running...
# 2025-01-08 08:55:12,888 - BasicDaemon - Background task running...
# 2025-01-08 08:55:14,892 - BasicDaemon - Background task running...
# 2025-01-08 08:55:16,894 - BasicDaemon - Background task running...
# 2025-01-08 08:55:18,898 - BasicDaemon - Background task running...
# 2025-01-08 08:55:20,902 - BasicDaemon - Background task running...
# 2025-01-08 08:55:22,905 - BasicDaemon - Background task running...
# 2025-01-08 08:55:24,908 - BasicDaemon - Background task running...
# 2025-01-08 08:55:26,912 - BasicDaemon - Background task running...
# 2025-01-08 08:55:28,915 - BasicDaemon - Background task running...
# 2025-01-08 08:55:30,917 - BasicDaemon - Background task running...
# 2025-01-08 08:55:32,920 - BasicDaemon - Background task running...
# 2025-01-08 08:55:34,924 - BasicDaemon - Background task running...
# 2025-01-08 08:55:36,926 - BasicDaemon - Background task running...
# 2025-01-08 08:55:38,928 - BasicDaemon - Background task running...
# 2025-01-08 08:55:40,930 - BasicDaemon - Background task running...
# 2025-01-08 08:55:42,932 - BasicDaemon - Background task running...
# 2025-01-08 08:55:44,933 - BasicDaemon - Background task running...
# 2025-01-08 08:55:46,934 - BasicDaemon - Background task running...
# 2025-01-08 08:55:48,937 - BasicDaemon - Background task running...
# 2025-01-08 08:55:50,939 - BasicDaemon - Background task running...
# 2025-01-08 08:55:52,942 - BasicDaemon - Background task running...
# 2025-01-08 08:55:54,945 - BasicDaemon - Background task running...
# 2025-01-08 08:55:56,947 - BasicDaemon - Background task running...
# 2025-01-08 08:55:58,949 - BasicDaemon - Background task running...
# 2025-01-08 08:56:00,952 - BasicDaemon - Background task running...
# 2025-01-08 08:56:02,953 - BasicDaemon - Background task running...
# 2025-01-08 08:56:04,955 - BasicDaemon - Background task running...
# 2025-01-08 08:56:06,958 - BasicDaemon - Background task running...
# 2025-01-08 08:56:08,960 - BasicDaemon - Background task running...
# 2025-01-08 08:56:10,963 - BasicDaemon - Background task running...
# 2025-01-08 08:56:12,966 - BasicDaemon - Background task running...
# 2025-01-08 08:56:14,969 - BasicDaemon - Background task running...
# 2025-01-08 08:56:16,972 - BasicDaemon - Background task running...
# 2025-01-08 08:56:18,977 - BasicDaemon - Background task running...
# 2025-01-08 08:56:20,979 - BasicDaemon - Background task running...
# 2025-01-08 08:56:22,982 - BasicDaemon - Background task running...
# 2025-01-08 08:56:24,984 - BasicDaemon - Background task running...
# 2025-01-08 08:56:26,986 - BasicDaemon - Background task running...
# 2025-01-08 08:56:28,988 - BasicDaemon - Background task running...
# 2025-01-08 08:56:30,991 - BasicDaemon - Background task running...
# 2025-01-08 08:56:32,996 - BasicDaemon - Background task running...
# 2025-01-08 08:56:34,999 - BasicDaemon - Background task running...
# 2025-01-08 08:56:37,001 - BasicDaemon - Background task running...
# 2025-01-08 08:56:39,004 - BasicDaemon - Background task running...
# 2025-01-08 08:56:41,007 - BasicDaemon - Background task running...
# 2025-01-08 08:56:43,009 - BasicDaemon - Background task running...
# 2025-01-08 08:56:45,012 - BasicDaemon - Background task running...
# 2025-01-08 08:56:47,014 - BasicDaemon - Background task running...
# 2025-01-08 08:56:49,016 - BasicDaemon - Background task running...
# 2025-01-08 08:56:51,018 - BasicDaemon - Background task running...
# 2025-01-08 08:56:53,020 - BasicDaemon - Background task running...
# 2025-01-08 08:56:55,024 - BasicDaemon - Background task running...
# 2025-01-08 08:56:57,026 - BasicDaemon - Background task running...
# 2025-01-08 08:56:59,029 - BasicDaemon - Background task running...
# 2025-01-08 08:57:01,031 - BasicDaemon - Background task running...
# 2025-01-08 08:57:03,033 - BasicDaemon - Background task running...
# 2025-01-08 08:57:05,037 - BasicDaemon - Background task running...
# 2025-01-08 08:57:07,039 - BasicDaemon - Background task running...
# 2025-01-08 08:57:09,042 - BasicDaemon - Background task running...
# 2025-01-08 08:57:11,043 - BasicDaemon - Background task running...
# 2025-01-08 08:57:13,045 - BasicDaemon - Background task running...
# 2025-01-08 08:57:15,046 - BasicDaemon - Background task running...
# 2025-01-08 08:57:17,050 - BasicDaemon - Background task running...
# 2025-01-08 08:57:19,053 - BasicDaemon - Background task running...
# 2025-01-08 08:57:21,055 - BasicDaemon - Background task running...
# 2025-01-08 08:57:23,059 - BasicDaemon - Background task running...
# 2025-01-08 08:57:25,061 - BasicDaemon - Background task running...
# 2025-01-08 08:57:27,062 - BasicDaemon - Background task running...
# 2025-01-08 08:57:29,064 - BasicDaemon - Background task running...
# 2025-01-08 08:57:31,066 - BasicDaemon - Background task running...
# 2025-01-08 08:57:33,068 - BasicDaemon - Background task running...
# 2025-01-08 08:57:35,071 - BasicDaemon - Background task running...
# 2025-01-08 08:57:37,074 - BasicDaemon - Background task running...
# 2025-01-08 08:57:39,077 - BasicDaemon - Background task running...
# 2025-01-08 08:57:41,079 - BasicDaemon - Background task running...
# 2025-01-08 08:57:43,081 - BasicDaemon - Background task running...
# 2025-01-08 08:57:45,083 - BasicDaemon - Background task running...
# 2025-01-08 08:57:47,085 - BasicDaemon - Background task running...
# 2025-01-08 08:57:49,086 - BasicDaemon - Background task running...
# 2025-01-08 08:57:51,088 - BasicDaemon - Background task running...
# 2025-01-08 08:57:53,091 - BasicDaemon - Background task running...
# 2025-01-08 08:57:55,095 - BasicDaemon - Background task running...
# 2025-01-08 08:57:57,097 - BasicDaemon - Background task running...
# 2025-01-08 08:57:59,100 - BasicDaemon - Background task running...
# 2025-01-08 08:58:01,103 - BasicDaemon - Background task running...
# 2025-01-08 08:58:03,105 - BasicDaemon - Background task running...
# 2025-01-08 08:58:05,108 - BasicDaemon - Background task running...
# 2025-01-08 08:58:07,111 - BasicDaemon - Background task running...
# 2025-01-08 08:58:09,114 - BasicDaemon - Background task running...
# 2025-01-08 08:58:11,117 - BasicDaemon - Background task running...
# 2025-01-08 08:58:13,121 - BasicDaemon - Background task running...
# 2025-01-08 08:58:15,123 - BasicDaemon - Background task running...
# 2025-01-08 08:58:17,126 - BasicDaemon - Background task running...
# 2025-01-08 08:58:19,129 - BasicDaemon - Background task running...
# 2025-01-08 08:58:21,133 - BasicDaemon - Background task running...
# 2025-01-08 08:58:23,136 - BasicDaemon - Background task running...
# 2025-01-08 08:58:25,138 - BasicDaemon - Background task running...
# 2025-01-08 08:58:27,141 - BasicDaemon - Background task running...
# 2025-01-08 08:58:29,144 - BasicDaemon - Background task running...
# 2025-01-08 08:58:31,147 - BasicDaemon - Background task running...
# 2025-01-08 08:58:33,150 - BasicDaemon - Background task running...
# 2025-01-08 08:58:35,154 - BasicDaemon - Background task running...
# 2025-01-08 08:58:37,156 - BasicDaemon - Background task running...
# 2025-01-08 08:58:39,159 - BasicDaemon - Background task running...
# 2025-01-08 08:58:41,162 - BasicDaemon - Background task running...
# 2025-01-08 08:58:43,163 - BasicDaemon - Background task running...
# 2025-01-08 08:58:45,166 - BasicDaemon - Background task running...
# 2025-01-08 08:58:47,170 - BasicDaemon - Background task running...
# 2025-01-08 08:58:49,172 - BasicDaemon - Background task running...
# 2025-01-08 08:58:51,175 - BasicDaemon - Background task running...
# 2025-01-08 08:58:53,177 - BasicDaemon - Background task running...
# 2025-01-08 08:58:55,180 - BasicDaemon - Background task running...
# 2025-01-08 08:58:57,181 - BasicDaemon - Background task running...
# 2025-01-08 08:58:59,184 - BasicDaemon - Background task running...
# 2025-01-08 08:59:01,186 - BasicDaemon - Background task running...
# 2025-01-08 08:59:03,189 - BasicDaemon - Background task running...
# 2025-01-08 08:59:05,193 - BasicDaemon - Background task running...
# 2025-01-08 08:59:07,195 - BasicDaemon - Background task running...
# 2025-01-08 08:59:09,199 - BasicDaemon - Background task running...
# 2025-01-08 08:59:11,201 - BasicDaemon - Background task running...
# 2025-01-08 08:59:13,203 - BasicDaemon - Background task running...
# 2025-01-08 08:59:15,206 - BasicDaemon - Background task running...
# 2025-01-08 08:59:17,208 - BasicDaemon - Background task running...
# 2025-01-08 08:59:19,211 - BasicDaemon - Background task running...
# 2025-01-08 08:59:21,214 - BasicDaemon - Background task running...
# 2025-01-08 08:59:23,216 - BasicDaemon - Background task running...
# 2025-01-08 08:59:25,220 - BasicDaemon - Background task running...
# 2025-01-08 08:59:27,221 - BasicDaemon - Background task running...
# 2025-01-08 08:59:29,225 - BasicDaemon - Background task running...
# 2025-01-08 08:59:31,227 - BasicDaemon - Background task running...
# 2025-01-08 08:59:33,230 - BasicDaemon - Background task running...
# 2025-01-08 08:59:35,236 - BasicDaemon - Background task running...
# 2025-01-08 08:59:37,238 - BasicDaemon - Background task running...
# 2025-01-08 08:59:39,241 - BasicDaemon - Background task running...
# 2025-01-08 08:59:41,244 - BasicDaemon - Background task running...
# 2025-01-08 08:59:43,248 - BasicDaemon - Background task running...
# 2025-01-08 08:59:45,252 - BasicDaemon - Background task running...
# 2025-01-08 08:59:47,254 - BasicDaemon - Background task running...
# 2025-01-08 08:59:49,256 - BasicDaemon - Background task running...
# 2025-01-08 08:59:51,259 - BasicDaemon - Background task running...
# 2025-01-08 08:59:53,261 - BasicDaemon - Background task running...
# 2025-01-08 08:59:55,265 - BasicDaemon - Background task running...
# 2025-01-08 08:59:57,268 - BasicDaemon - Background task running...
# 2025-01-08 08:59:59,272 - BasicDaemon - Background task running...
# 2025-01-08 09:00:01,275 - BasicDaemon - Background task running...
# 2025-01-08 09:00:03,277 - BasicDaemon - Background task running...
# 2025-01-08 09:00:05,279 - BasicDaemon - Background task running...
# 2025-01-08 09:00:07,281 - BasicDaemon - Background task running...
# 2025-01-08 09:00:09,283 - BasicDaemon - Background task running...
# 2025-01-08 09:00:11,286 - BasicDaemon - Background task running...
# 2025-01-08 09:00:13,289 - BasicDaemon - Background task running...
# 2025-01-08 09:00:15,291 - BasicDaemon - Background task running...
# 2025-01-08 09:00:17,293 - BasicDaemon - Background task running...
# 2025-01-08 09:00:19,295 - BasicDaemon - Background task running...
# 2025-01-08 09:00:21,298 - BasicDaemon - Background task running...
# 2025-01-08 09:00:23,299 - BasicDaemon - Background task running...
# 2025-01-08 09:00:25,302 - BasicDaemon - Background task running...
# 2025-01-08 09:00:27,304 - BasicDaemon - Background task running...
# 2025-01-08 09:00:29,306 - BasicDaemon - Background task running...
# 2025-01-08 09:00:31,309 - BasicDaemon - Background task running...
# 2025-01-08 09:00:33,312 - BasicDaemon - Background task running...
# 2025-01-08 09:00:35,316 - BasicDaemon - Background task running...
# 2025-01-08 09:00:37,318 - BasicDaemon - Background task running...
# 2025-01-08 09:00:39,322 - BasicDaemon - Background task running...
# 2025-01-08 09:00:41,326 - BasicDaemon - Background task running...
# 2025-01-08 09:00:43,328 - BasicDaemon - Background task running...
# 2025-01-08 09:00:45,329 - BasicDaemon - Background task running...
# 2025-01-08 09:00:47,331 - BasicDaemon - Background task running...
# 2025-01-08 09:00:49,333 - BasicDaemon - Background task running...
# 2025-01-08 09:00:51,335 - BasicDaemon - Background task running...
# 2025-01-08 09:00:53,338 - BasicDaemon - Background task running...
# 2025-01-08 09:00:55,340 - BasicDaemon - Background task running...
# 2025-01-08 09:00:57,342 - BasicDaemon - Background task running...
# 2025-01-08 09:00:59,346 - BasicDaemon - Background task running...
# 2025-01-08 09:01:01,348 - BasicDaemon - Background task running...
# 2025-01-08 09:01:03,350 - BasicDaemon - Background task running...
# 2025-01-08 09:01:05,353 - BasicDaemon - Background task running...
# 2025-01-08 09:01:07,355 - BasicDaemon - Background task running...
# 2025-01-08 09:01:09,357 - BasicDaemon - Background task running...
# 2025-01-08 09:01:11,359 - BasicDaemon - Background task running...
# 2025-01-08 09:01:13,363 - BasicDaemon - Background task running...
# 2025-01-08 09:01:15,365 - BasicDaemon - Background task running...
# 2025-01-08 09:01:17,367 - BasicDaemon - Background task running...
# 2025-01-08 09:01:19,370 - BasicDaemon - Background task running...
# 2025-01-08 09:01:21,374 - BasicDaemon - Background task running...
# 2025-01-08 09:01:23,376 - BasicDaemon - Background task running...
# 2025-01-08 09:01:25,378 - BasicDaemon - Background task running...
# 2025-01-08 09:01:27,380 - BasicDaemon - Background task running...
# 2025-01-08 09:01:29,384 - BasicDaemon - Background task running...
# 2025-01-08 09:01:31,387 - BasicDaemon - Background task running...
# 2025-01-08 09:01:33,391 - BasicDaemon - Background task running...
# 2025-01-08 09:01:35,394 - BasicDaemon - Background task running...
# 2025-01-08 09:01:37,397 - BasicDaemon - Background task running...
# 2025-01-08 09:01:39,399 - BasicDaemon - Background task running...
# 2025-01-08 09:01:41,401 - BasicDaemon - Background task running...
# 2025-01-08 09:01:43,406 - BasicDaemon - Background task running...
# 2025-01-08 09:01:45,408 - BasicDaemon - Background task running...
# 2025-01-08 09:01:47,409 - BasicDaemon - Background task running...
# 2025-01-08 09:01:49,412 - BasicDaemon - Background task running...
# 2025-01-08 09:01:51,415 - BasicDaemon - Background task running...
# 2025-01-08 09:01:53,417 - BasicDaemon - Background task running...
# 2025-01-08 09:01:55,420 - BasicDaemon - Background task running...
# 2025-01-08 09:01:57,423 - BasicDaemon - Background task running...
# 2025-01-08 09:01:59,425 - BasicDaemon - Background task running...
# 2025-01-08 09:02:01,430 - BasicDaemon - Background task running...
# 2025-01-08 09:02:03,432 - BasicDaemon - Background task running...
# 2025-01-08 09:02:05,435 - BasicDaemon - Background task running...
# 2025-01-08 09:02:07,437 - BasicDaemon - Background task running...
# 2025-01-08 09:02:09,440 - BasicDaemon - Background task running...
# 2025-01-08 09:02:11,444 - BasicDaemon - Background task running...
# 2025-01-08 09:02:13,446 - BasicDaemon - Background task running...
# 2025-01-08 09:02:15,447 - BasicDaemon - Background task running...
# 2025-01-08 09:02:17,450 - BasicDaemon - Background task running...
# 2025-01-08 09:02:19,453 - BasicDaemon - Background task running...
# 2025-01-08 09:02:21,456 - BasicDaemon - Background task running...
# 2025-01-08 09:02:23,460 - BasicDaemon - Background task running...
# 2025-01-08 09:02:25,462 - BasicDaemon - Background task running...
# 2025-01-08 09:02:27,464 - BasicDaemon - Background task running...
# 2025-01-08 09:02:29,467 - BasicDaemon - Background task running...
# 2025-01-08 09:02:31,470 - BasicDaemon - Background task running...
# 2025-01-08 09:02:33,474 - BasicDaemon - Background task running...
# 2025-01-08 09:02:35,475 - BasicDaemon - Background task running...
# 2025-01-08 09:02:37,479 - BasicDaemon - Background task running...
# 2025-01-08 09:02:39,482 - BasicDaemon - Background task running...
# 2025-01-08 09:02:41,485 - BasicDaemon - Background task running...
# 2025-01-08 09:02:43,486 - BasicDaemon - Background task running...
# 2025-01-08 09:02:45,488 - BasicDaemon - Background task running...
# 2025-01-08 09:02:47,491 - BasicDaemon - Background task running...
# 2025-01-08 09:02:49,496 - BasicDaemon - Background task running...
# 2025-01-08 09:02:51,499 - BasicDaemon - Background task running...
# 2025-01-08 09:02:53,502 - BasicDaemon - Background task running...
# 2025-01-08 09:02:55,504 - BasicDaemon - Background task running...
# 2025-01-08 09:02:57,506 - BasicDaemon - Background task running...
# 2025-01-08 09:02:59,508 - BasicDaemon - Background task running...
# 2025-01-08 09:03:01,509 - BasicDaemon - Background task running...
# 2025-01-08 09:03:03,511 - BasicDaemon - Background task running...
# 2025-01-08 09:03:05,512 - BasicDaemon - Background task running...
# 2025-01-08 09:03:07,514 - BasicDaemon - Background task running...
# 2025-01-08 09:03:09,516 - BasicDaemon - Background task running...
# 2025-01-08 09:03:11,519 - BasicDaemon - Background task running...
# 2025-01-08 09:03:13,522 - BasicDaemon - Background task running...
# 2025-01-08 09:03:15,525 - BasicDaemon - Background task running...
# 2025-01-08 09:03:17,527 - BasicDaemon - Background task running...
# 2025-01-08 09:03:19,529 - BasicDaemon - Background task running...
# 2025-01-08 09:03:21,530 - BasicDaemon - Background task running...
# 2025-01-08 09:03:23,532 - BasicDaemon - Background task running...
# 2025-01-08 09:03:25,535 - BasicDaemon - Background task running...
# 2025-01-08 09:03:27,536 - BasicDaemon - Background task running...
# 2025-01-08 09:03:29,541 - BasicDaemon - Background task running...
# 2025-01-08 09:03:31,544 - BasicDaemon - Background task running...
# 2025-01-08 09:03:33,548 - BasicDaemon - Background task running...
# 2025-01-08 09:03:35,550 - BasicDaemon - Background task running...
# 2025-01-08 09:03:37,552 - BasicDaemon - Background task running...
# 2025-01-08 09:03:39,555 - BasicDaemon - Background task running...
# 2025-01-08 09:03:41,557 - BasicDaemon - Background task running...
# 2025-01-08 09:03:43,560 - BasicDaemon - Background task running...
# 2025-01-08 09:03:45,562 - BasicDaemon - Background task running...
# 2025-01-08 09:03:47,565 - BasicDaemon - Background task running...
# 2025-01-08 09:03:49,567 - BasicDaemon - Background task running...
# 2025-01-08 09:03:51,570 - BasicDaemon - Background task running...
# 2025-01-08 09:03:53,572 - BasicDaemon - Background task running...
# 2025-01-08 09:03:55,575 - BasicDaemon - Background task running...
# 2025-01-08 09:03:57,576 - BasicDaemon - Background task running...
# 2025-01-08 09:03:59,579 - BasicDaemon - Background task running...
# 2025-01-08 09:04:01,583 - BasicDaemon - Background task running...
# 2025-01-08 09:04:03,587 - BasicDaemon - Background task running...
# 2025-01-08 09:04:05,591 - BasicDaemon - Background task running...
# 2025-01-08 09:04:07,593 - BasicDaemon - Background task running...
# 2025-01-08 09:04:09,595 - BasicDaemon - Background task running...
# 2025-01-08 09:04:11,597 - BasicDaemon - Background task running...
# 2025-01-08 09:04:13,599 - BasicDaemon - Background task running...
# 2025-01-08 09:04:15,600 - BasicDaemon - Background task running...
# 2025-01-08 09:04:17,605 - BasicDaemon - Background task running...
# 2025-01-08 09:04:19,607 - BasicDaemon - Background task running...
# 2025-01-08 09:04:21,611 - BasicDaemon - Background task running...
# 2025-01-08 09:04:23,614 - BasicDaemon - Background task running...
# 2025-01-08 09:04:25,617 - BasicDaemon - Background task running...
# 2025-01-08 09:04:27,618 - BasicDaemon - Background task running...
# 2025-01-08 09:04:29,621 - BasicDaemon - Background task running...
# 2025-01-08 09:04:31,623 - BasicDaemon - Background task running...
# 2025-01-08 09:04:33,624 - BasicDaemon - Background task running...
# 2025-01-08 09:04:35,626 - BasicDaemon - Background task running...
# 2025-01-08 09:04:37,631 - BasicDaemon - Background task running...
# 2025-01-08 09:04:39,633 - BasicDaemon - Background task running...
# 2025-01-08 09:04:41,635 - BasicDaemon - Background task running...
# 2025-01-08 09:04:43,639 - BasicDaemon - Background task running...
# 2025-01-08 09:04:45,640 - BasicDaemon - Background task running...
# 2025-01-08 09:04:47,643 - BasicDaemon - Background task running...
# 2025-01-08 09:04:49,645 - BasicDaemon - Background task running...
# 2025-01-08 09:04:51,647 - BasicDaemon - Background task running...
# 2025-01-08 09:04:53,650 - BasicDaemon - Background task running...
# 2025-01-08 09:04:55,651 - BasicDaemon - Background task running...
# 2025-01-08 09:04:57,661 - BasicDaemon - Background task running...
# 2025-01-08 09:04:59,668 - BasicDaemon - Background task running...
# 2025-01-08 09:05:01,670 - BasicDaemon - Background task running...
# 2025-01-08 09:05:03,672 - BasicDaemon - Background task running...
# 2025-01-08 09:05:05,682 - BasicDaemon - Background task running...
# 2025-01-08 09:05:07,685 - BasicDaemon - Background task running...
# 2025-01-08 09:05:09,687 - BasicDaemon - Background task running...
# 2025-01-08 09:05:11,689 - BasicDaemon - Background task running...
# 2025-01-08 09:05:13,691 - BasicDaemon - Background task running...
# 2025-01-08 09:05:15,700 - BasicDaemon - Background task running...
# 2025-01-08 09:05:17,703 - BasicDaemon - Background task running...
# 2025-01-08 09:05:19,706 - BasicDaemon - Background task running...
# 2025-01-08 09:05:21,708 - BasicDaemon - Background task running...
# 2025-01-08 09:05:23,710 - BasicDaemon - Background task running...
# 2025-01-08 09:05:25,723 - BasicDaemon - Background task running...
# 2025-01-08 09:05:27,724 - BasicDaemon - Background task running...
# 2025-01-08 09:05:29,728 - BasicDaemon - Background task running...
# 2025-01-08 09:05:31,731 - BasicDaemon - Background task running...
# 2025-01-08 09:05:33,733 - BasicDaemon - Background task running...
# 2025-01-08 09:05:35,735 - BasicDaemon - Background task running...
# 2025-01-08 09:05:37,738 - BasicDaemon - Background task running...
# 2025-01-08 09:05:39,740 - BasicDaemon - Background task running...
# 2025-01-08 09:05:41,742 - BasicDaemon - Background task running...
# 2025-01-08 09:05:43,746 - BasicDaemon - Background task running...
# 2025-01-08 09:05:45,749 - BasicDaemon - Background task running...
# 2025-01-08 09:05:47,753 - BasicDaemon - Background task running...
# 2025-01-08 09:05:49,755 - BasicDaemon - Background task running...
# 2025-01-08 09:05:51,757 - BasicDaemon - Background task running...
# 2025-01-08 09:05:53,759 - BasicDaemon - Background task running...
# 2025-01-08 09:05:55,761 - BasicDaemon - Background task running...
# 2025-01-08 09:05:57,764 - BasicDaemon - Background task running...
# 2025-01-08 09:05:59,765 - BasicDaemon - Background task running...
# 2025-01-08 09:06:01,768 - BasicDaemon - Background task running...
# 2025-01-08 09:06:03,773 - BasicDaemon - Background task running...
# 2025-01-08 09:06:05,777 - BasicDaemon - Background task running...
# 2025-01-08 09:06:07,782 - BasicDaemon - Background task running...
# 2025-01-08 09:06:09,785 - BasicDaemon - Background task running...
# 2025-01-08 09:06:11,787 - BasicDaemon - Background task running...
# 2025-01-08 09:06:13,789 - BasicDaemon - Background task running...
# 2025-01-08 09:06:15,791 - BasicDaemon - Background task running...
# 2025-01-08 09:06:17,797 - BasicDaemon - Background task running...
# 2025-01-08 09:06:19,801 - BasicDaemon - Background task running...
# 2025-01-08 09:06:21,804 - BasicDaemon - Background task running...
# 2025-01-08 09:06:23,805 - BasicDaemon - Background task running...
# 2025-01-08 09:06:25,809 - BasicDaemon - Background task running...
# 2025-01-08 09:06:27,812 - BasicDaemon - Background task running...
# 2025-01-08 09:06:29,814 - BasicDaemon - Background task running...
# 2025-01-08 09:06:31,817 - BasicDaemon - Background task running...
# 2025-01-08 09:06:33,824 - BasicDaemon - Background task running...
# 2025-01-08 09:06:35,826 - BasicDaemon - Background task running...
# 2025-01-08 09:06:37,828 - BasicDaemon - Background task running...
# 2025-01-08 09:06:39,830 - BasicDaemon - Background task running...
# 2025-01-08 09:06:41,833 - BasicDaemon - Background task running...
# 2025-01-08 09:06:43,837 - BasicDaemon - Background task running...
# 2025-01-08 09:06:45,838 - BasicDaemon - Background task running...
# 2025-01-08 09:06:47,839 - BasicDaemon - Background task running...
# 2025-01-08 09:06:49,842 - BasicDaemon - Background task running...
# 2025-01-08 09:06:51,845 - BasicDaemon - Background task running...
# 2025-01-08 09:06:53,846 - BasicDaemon - Background task running...
# 2025-01-08 09:06:55,851 - BasicDaemon - Background task running...
# 2025-01-08 09:06:57,853 - BasicDaemon - Background task running...
# 2025-01-08 09:06:59,857 - BasicDaemon - Background task running...
# 2025-01-08 09:07:01,858 - BasicDaemon - Background task running...
# 2025-01-08 09:07:03,861 - BasicDaemon - Background task running...
# 2025-01-08 09:07:05,864 - BasicDaemon - Background task running...
# 2025-01-08 09:07:07,866 - BasicDaemon - Background task running...
# 2025-01-08 09:07:09,868 - BasicDaemon - Background task running...
# 2025-01-08 09:07:11,870 - BasicDaemon - Background task running...
# 2025-01-08 09:07:13,872 - BasicDaemon - Background task running...
# 2025-01-08 09:07:15,876 - BasicDaemon - Background task running...
# 2025-01-08 09:07:17,880 - BasicDaemon - Background task running...
# 2025-01-08 09:07:19,881 - BasicDaemon - Background task running...
# 2025-01-08 09:07:21,886 - BasicDaemon - Background task running...
# 2025-01-08 09:07:23,889 - BasicDaemon - Background task running...
# 2025-01-08 09:07:25,894 - BasicDaemon - Background task running...
# 2025-01-08 09:07:27,895 - BasicDaemon - Background task running...
# 2025-01-08 09:07:29,898 - BasicDaemon - Background task running...
# 2025-01-08 09:07:31,900 - BasicDaemon - Background task running...
# 2025-01-08 09:07:33,902 - BasicDaemon - Background task running...
# 2025-01-08 09:07:35,904 - BasicDaemon - Background task running...
# 2025-01-08 09:07:37,907 - BasicDaemon - Background task running...
# 2025-01-08 09:07:39,909 - BasicDaemon - Background task running...
# 2025-01-08 09:07:41,912 - BasicDaemon - Background task running...
# 2025-01-08 09:07:43,913 - BasicDaemon - Background task running...
# 2025-01-08 09:07:45,915 - BasicDaemon - Background task running...
# 2025-01-08 09:07:47,918 - BasicDaemon - Background task running...
# 2025-01-08 09:07:49,919 - BasicDaemon - Background task running...
# 2025-01-08 09:07:51,932 - BasicDaemon - Background task running...
# 2025-01-08 09:07:53,937 - BasicDaemon - Background task running...
# 2025-01-08 09:07:55,939 - BasicDaemon - Background task running...
# 2025-01-08 09:07:57,941 - BasicDaemon - Background task running...
# 2025-01-08 09:07:59,944 - BasicDaemon - Background task running...
# 2025-01-08 09:08:01,947 - BasicDaemon - Background task running...
# 2025-01-08 09:08:03,951 - BasicDaemon - Background task running...
# 2025-01-08 09:08:05,954 - BasicDaemon - Background task running...
# 2025-01-08 09:08:07,956 - BasicDaemon - Background task running...
# 2025-01-08 09:08:09,957 - BasicDaemon - Background task running...
# 2025-01-08 09:08:11,959 - BasicDaemon - Background task running...
# 2025-01-08 09:08:13,961 - BasicDaemon - Background task running...
# 2025-01-08 09:08:15,963 - BasicDaemon - Background task running...
# 2025-01-08 09:08:17,965 - BasicDaemon - Background task running...
# 2025-01-08 09:08:19,968 - BasicDaemon - Background task running...
# 2025-01-08 09:08:21,974 - BasicDaemon - Background task running...
# 2025-01-08 09:08:23,977 - BasicDaemon - Background task running...
# 2025-01-08 09:08:25,980 - BasicDaemon - Background task running...
# 2025-01-08 09:08:27,988 - BasicDaemon - Background task running...
# 2025-01-08 09:08:29,991 - BasicDaemon - Background task running...
# 2025-01-08 09:08:31,993 - BasicDaemon - Background task running...
# 2025-01-08 09:08:33,996 - BasicDaemon - Background task running...
# 2025-01-08 09:08:35,998 - BasicDaemon - Background task running...
# 2025-01-08 09:08:38,000 - BasicDaemon - Background task running...
# 2025-01-08 09:08:40,003 - BasicDaemon - Background task running...
# 2025-01-08 09:08:42,005 - BasicDaemon - Background task running...
# 2025-01-08 09:08:44,008 - BasicDaemon - Background task running...
# 2025-01-08 09:08:46,011 - BasicDaemon - Background task running...
# 2025-01-08 09:08:48,013 - BasicDaemon - Background task running...
# 2025-01-08 09:08:50,015 - BasicDaemon - Background task running...
# 2025-01-08 09:08:52,017 - BasicDaemon - Background task running...
# 2025-01-08 09:08:54,019 - BasicDaemon - Background task running...
# 2025-01-08 09:08:56,020 - BasicDaemon - Background task running...
# 2025-01-08 09:08:58,022 - BasicDaemon - Background task running...
# 2025-01-08 09:09:00,024 - BasicDaemon - Background task running...
# 2025-01-08 09:09:02,026 - BasicDaemon - Background task running...
# 2025-01-08 09:09:04,027 - BasicDaemon - Background task running...
# 2025-01-08 09:09:06,029 - BasicDaemon - Background task running...
# 2025-01-08 09:09:08,031 - BasicDaemon - Background task running...
# 2025-01-08 09:09:10,033 - BasicDaemon - Background task running...
# 2025-01-08 09:09:12,037 - BasicDaemon - Background task running...
# 2025-01-08 09:09:14,039 - BasicDaemon - Background task running...
# 2025-01-08 09:09:16,041 - BasicDaemon - Background task running...
# 2025-01-08 09:09:18,043 - BasicDaemon - Background task running...
# 2025-01-08 09:09:20,046 - BasicDaemon - Background task running...
# 2025-01-08 09:09:22,049 - BasicDaemon - Background task running...
# 2025-01-08 09:09:24,051 - BasicDaemon - Background task running...
# 2025-01-08 09:09:26,053 - BasicDaemon - Background task running...
# 2025-01-08 09:09:28,057 - BasicDaemon - Background task running...
# 2025-01-08 09:09:30,060 - BasicDaemon - Background task running...
# 2025-01-08 09:09:32,064 - BasicDaemon - Background task running...
# 2025-01-08 09:09:34,065 - BasicDaemon - Background task running...
# 2025-01-08 09:09:36,066 - BasicDaemon - Background task running...
# 2025-01-08 09:09:38,067 - BasicDaemon - Background task running...
# 2025-01-08 09:09:40,068 - BasicDaemon - Background task running...
# 2025-01-08 09:09:42,071 - BasicDaemon - Background task running...
# 2025-01-08 09:09:44,074 - BasicDaemon - Background task running...
# 2025-01-08 09:09:46,076 - BasicDaemon - Background task running...
# 2025-01-08 09:09:48,079 - BasicDaemon - Background task running...
# 2025-01-08 09:09:50,081 - BasicDaemon - Background task running...
# 2025-01-08 09:09:52,083 - BasicDaemon - Background task running...
# 2025-01-08 09:09:54,086 - BasicDaemon - Background task running...
# 2025-01-08 09:09:56,088 - BasicDaemon - Background task running...
# 2025-01-08 09:09:58,091 - BasicDaemon - Background task running...
# 2025-01-08 09:10:00,094 - BasicDaemon - Background task running...
# 2025-01-08 09:10:02,096 - BasicDaemon - Background task running...
# 2025-01-08 09:10:04,099 - BasicDaemon - Background task running...
# 2025-01-08 09:10:06,102 - BasicDaemon - Background task running...
# 2025-01-08 09:10:08,104 - BasicDaemon - Background task running...
# 2025-01-08 09:10:10,105 - BasicDaemon - Background task running...
# 2025-01-08 09:10:12,108 - BasicDaemon - Background task running...
# 2025-01-08 09:10:14,110 - BasicDaemon - Background task running...
# 2025-01-08 09:10:16,111 - BasicDaemon - Background task running...
# 2025-01-08 09:10:18,113 - BasicDaemon - Background task running...
# 2025-01-08 09:10:20,119 - BasicDaemon - Background task running...
# 2025-01-08 09:10:22,122 - BasicDaemon - Background task running...
# 2025-01-08 09:10:24,125 - BasicDaemon - Background task running...
# 2025-01-08 09:10:26,128 - BasicDaemon - Background task running...
# 2025-01-08 09:10:28,130 - BasicDaemon - Background task running...
# 2025-01-08 09:10:30,133 - BasicDaemon - Background task running...
# 2025-01-08 09:10:32,137 - BasicDaemon - Background task running...
# 2025-01-08 09:10:34,139 - BasicDaemon - Background task running...
# 2025-01-08 09:10:36,142 - BasicDaemon - Background task running...
# 2025-01-08 09:10:38,145 - BasicDaemon - Background task running...
# 2025-01-08 09:10:40,149 - BasicDaemon - Background task running...
# 2025-01-08 09:10:42,151 - BasicDaemon - Background task running...
# 2025-01-08 09:10:44,153 - BasicDaemon - Background task running...
# 2025-01-08 09:10:46,156 - BasicDaemon - Background task running...
# 2025-01-08 09:10:48,158 - BasicDaemon - Background task running...
# 2025-01-08 09:10:50,161 - BasicDaemon - Background task running...
# 2025-01-08 09:10:52,163 - BasicDaemon - Background task running...
# 2025-01-08 09:10:54,165 - BasicDaemon - Background task running...
# 2025-01-08 09:10:56,167 - BasicDaemon - Background task running...
# 2025-01-08 09:10:58,169 - BasicDaemon - Background task running...
# 2025-01-08 09:11:00,172 - BasicDaemon - Background task running...
# 2025-01-08 09:11:02,174 - BasicDaemon - Background task running...
# 2025-01-08 09:11:04,177 - BasicDaemon - Background task running...
# 2025-01-08 09:11:06,180 - BasicDaemon - Background task running...
# 2025-01-08 09:11:08,182 - BasicDaemon - Background task running...
# 2025-01-08 09:11:10,183 - BasicDaemon - Background task running...
# 2025-01-08 09:11:12,187 - BasicDaemon - Background task running...
# 2025-01-08 09:11:14,190 - BasicDaemon - Background task running...
# 2025-01-08 09:11:16,193 - BasicDaemon - Background task running...
# 2025-01-08 09:11:18,195 - BasicDaemon - Background task running...
# 2025-01-08 09:11:20,198 - BasicDaemon - Background task running...
# 2025-01-08 09:11:22,200 - BasicDaemon - Background task running...
# 2025-01-08 09:11:24,203 - BasicDaemon - Background task running...
# 2025-01-08 09:11:26,205 - BasicDaemon - Background task running...
# 2025-01-08 09:11:28,206 - BasicDaemon - Background task running...
# 2025-01-08 09:11:30,208 - BasicDaemon - Background task running...
# 2025-01-08 09:11:32,210 - BasicDaemon - Background task running...
# 2025-01-08 09:11:34,214 - BasicDaemon - Background task running...
# 2025-01-08 09:11:36,218 - BasicDaemon - Background task running...
# 2025-01-08 09:11:38,220 - BasicDaemon - Background task running...
# 2025-01-08 09:11:40,222 - BasicDaemon - Background task running...
# 2025-01-08 09:11:42,224 - BasicDaemon - Background task running...
# 2025-01-08 09:11:44,227 - BasicDaemon - Background task running...
# ...
# 2025-01-08 15:21:59,926 - BasicDaemon - Background task running...
# 2025-01-08 15:22:01,928 - BasicDaemon - Background task running...
# 2025-01-08 15:22:03,931 - BasicDaemon - Background task running...
# 2025-01-08 15:22:05,934 - BasicDaemon - Background task running...
# 2025-01-08 15:22:07,936 - BasicDaemon - Background task running...
# 2025-01-08 15:22:09,938 - BasicDaemon - Background task running...
# 2025-01-08 15:22:11,940 - BasicDaemon - Background task running...
# 2025-01-08 15:22:13,943 - BasicDaemon - Background task running...
# 2025-01-08 15:22:15,946 - BasicDaemon - Background task running...
# 2025-01-08 15:22:17,949 - BasicDaemon - Background task running...
# 2025-01-08 15:22:19,952 - BasicDaemon - Background task running...
# 2025-01-08 15:22:21,953 - BasicDaemon - Background task running...
# 2025-01-08 15:22:23,956 - BasicDaemon - Background task running...
# 2025-01-08 15:22:25,957 - BasicDaemon - Background task running...
# 2025-01-08 15:22:27,960 - BasicDaemon - Background task running...
# 2025-01-08 15:22:29,963 - BasicDaemon - Background task running...
# 2025-01-08 15:22:31,965 - BasicDaemon - Background task running...
# 2025-01-08 15:22:33,967 - BasicDaemon - Background task running...
# 2025-01-08 15:22:35,969 - BasicDaemon - Background task running...
# 2025-01-08 15:22:37,971 - BasicDaemon - Background task running...
# 2025-01-08 15:22:39,973 - BasicDaemon - Background task running...
# 2025-01-08 15:22:41,976 - BasicDaemon - Background task running...
# 2025-01-08 15:22:43,977 - BasicDaemon - Background task running...
# 2025-01-08 15:22:45,979 - BasicDaemon - Background task running...
# 2025-01-08 15:22:47,982 - BasicDaemon - Background task running...
# 2025-01-08 15:22:49,983 - BasicDaemon - Background task running...
# 2025-01-08 15:22:51,985 - BasicDaemon - Background task running...
# 2025-01-08 15:22:53,988 - BasicDaemon - Background task running...
# 2025-01-08 15:22:55,989 - BasicDaemon - Background task running...
# 2025-01-08 15:22:57,991 - BasicDaemon - Background task running...
# 2025-01-08 15:22:59,994 - BasicDaemon - Background task running...
# 2025-01-08 15:23:01,996 - BasicDaemon - Background task running...
# 2025-01-08 15:23:03,997 - BasicDaemon - Background task running...
# 2025-01-08 15:23:06,000 - BasicDaemon - Background task running...
# 2025-01-08 15:23:08,001 - BasicDaemon - Background task running...
# 2025-01-08 15:23:10,003 - BasicDaemon - Background task running...
# 2025-01-08 15:23:12,005 - BasicDaemon - Background task running...
# 2025-01-08 15:23:14,007 - BasicDaemon - Background task running...
# 2025-01-08 15:23:16,009 - BasicDaemon - Background task running...
# 2025-01-08 15:23:18,010 - BasicDaemon - Background task running...
# 2025-01-08 15:23:20,011 - BasicDaemon - Background task running...
# 2025-01-08 15:23:22,012 - BasicDaemon - Background task running...
# 2025-01-08 15:23:24,014 - BasicDaemon - Background task running...
# 2025-01-08 15:23:26,017 - BasicDaemon - Background task running...
# 2025-01-08 15:23:28,020 - BasicDaemon - Background task running...
# 2025-01-08 15:23:30,024 - BasicDaemon - Background task running...
# 2025-01-08 15:23:32,026 - BasicDaemon - Background task running...
# 2025-01-08 15:23:34,028 - BasicDaemon - Background task running...
# 2025-01-08 15:23:36,031 - BasicDaemon - Background task running...
# 2025-01-08 15:23:38,033 - BasicDaemon - Background task running...
# 2025-01-08 15:23:40,036 - BasicDaemon - Background task running...
# 2025-01-08 15:23:42,038 - BasicDaemon - Background task running...
# 2025-01-08 15:23:44,041 - BasicDaemon - Background task running...
# 2025-01-08 15:23:46,043 - BasicDaemon - Background task running...
# 2025-01-08 15:23:48,045 - BasicDaemon - Background task running...
# 2025-01-08 15:23:50,046 - BasicDaemon - Background task running...
# 2025-01-08 15:23:52,048 - BasicDaemon - Background task running...
# 2025-01-08 15:23:54,049 - BasicDaemon - Background task running...
# 2025-01-08 15:23:56,058 - BasicDaemon - Background task running...
# 2025-01-08 15:23:58,062 - BasicDaemon - Background task running...
# 2025-01-08 15:24:00,064 - BasicDaemon - Background task running...
# 2025-01-08 15:24:02,066 - BasicDaemon - Background task running...
# 2025-01-08 15:24:04,067 - BasicDaemon - Background task running...
# 2025-01-08 15:24:06,070 - BasicDaemon - Background task running...
# 2025-01-08 15:24:08,072 - BasicDaemon - Background task running...
# 2025-01-08 15:24:10,073 - BasicDaemon - Background task running...
# 2025-01-08 15:24:12,075 - BasicDaemon - Background task running...
# 2025-01-08 15:24:14,077 - BasicDaemon - Background task running...
# 2025-01-08 15:24:16,078 - BasicDaemon - Background task running...
# 2025-01-08 15:24:18,080 - BasicDaemon - Background task running...
# 2025-01-08 15:24:20,082 - BasicDaemon - Background task running...
# 2025-01-08 15:24:22,084 - BasicDaemon - Background task running...
# 2025-01-08 15:24:24,087 - BasicDaemon - Background task running...
# 2025-01-08 15:24:26,090 - BasicDaemon - Background task running...
# 2025-01-08 15:24:28,095 - BasicDaemon - Background task running...
# 2025-01-08 15:24:30,098 - BasicDaemon - Background task running...
# 2025-01-08 15:24:32,102 - BasicDaemon - Background task running...
# 2025-01-08 15:24:34,105 - BasicDaemon - Background task running...
# 2025-01-08 15:24:36,108 - BasicDaemon - Background task running...
# 2025-01-08 15:24:38,112 - BasicDaemon - Background task running...
# 2025-01-08 15:24:40,115 - BasicDaemon - Background task running...
# 2025-01-08 15:24:42,118 - BasicDaemon - Background task running...
# 2025-01-08 15:24:44,120 - BasicDaemon - Background task running...
# 2025-01-08 15:24:46,122 - BasicDaemon - Background task running...
# 2025-01-08 15:24:48,125 - BasicDaemon - Background task running...
# 2025-01-08 15:24:50,127 - BasicDaemon - Background task running...
# 2025-01-08 15:24:52,129 - BasicDaemon - Background task running...
# 2025-01-08 15:24:54,131 - BasicDaemon - Background task running...
# 2025-01-08 15:24:56,133 - BasicDaemon - Background task running...
# 2025-01-08 15:24:58,136 - BasicDaemon - Background task running...
# 2025-01-08 15:25:00,138 - BasicDaemon - Background task running...
# 2025-01-08 15:25:02,140 - BasicDaemon - Background task running...
# 2025-01-08 15:25:04,143 - BasicDaemon - Background task running...
# 2025-01-08 15:25:06,145 - BasicDaemon - Background task running...
# 2025-01-08 15:25:08,146 - BasicDaemon - Background task running...
# 2025-01-08 15:25:10,148 - BasicDaemon - Background task running...
# 2025-01-08 15:25:12,150 - BasicDaemon - Background task running...
# 2025-01-08 15:25:14,151 - BasicDaemon - Background task running...
# 2025-01-08 15:25:16,153 - BasicDaemon - Background task running...
# 2025-01-08 15:25:18,154 - BasicDaemon - Background task running...
# 2025-01-08 15:25:20,157 - BasicDaemon - Background task running...
# 2025-01-08 15:25:22,159 - BasicDaemon - Background task running...
# 2025-01-08 15:25:24,162 - BasicDaemon - Background task running...
# 2025-01-08 15:25:26,165 - BasicDaemon - Background task running...
# 2025-01-08 15:25:28,167 - BasicDaemon - Background task running...
# 2025-01-08 15:25:30,170 - BasicDaemon - Background task running...
# 2025-01-08 15:25:32,172 - BasicDaemon - Background task running...
# 2025-01-08 15:25:34,174 - BasicDaemon - Background task running...
# 2025-01-08 15:25:36,176 - BasicDaemon - Background task running...
# 2025-01-08 15:25:38,179 - BasicDaemon - Background task running...
# 2025-01-08 15:25:40,182 - BasicDaemon - Background task running...
# 2025-01-08 15:25:42,184 - BasicDaemon - Background task running...
# 2025-01-08 15:25:44,187 - BasicDaemon - Background task running...
# 2025-01-08 15:25:46,190 - BasicDaemon - Background task running...
# 2025-01-08 15:25:48,192 - BasicDaemon - Background task running...
# 2025-01-08 15:25:50,195 - BasicDaemon - Background task running...
# 2025-01-08 15:25:52,197 - BasicDaemon - Background task running...
# 2025-01-08 15:25:54,199 - BasicDaemon - Background task running...
# 2025-01-08 15:25:56,202 - BasicDaemon - Background task running...
# 2025-01-08 15:25:58,204 - BasicDaemon - Background task running...
# 2025-01-08 15:26:00,206 - BasicDaemon - Background task running...
# 2025-01-08 15:26:02,208 - BasicDaemon - Background task running...
# 2025-01-08 15:26:04,210 - BasicDaemon - Background task running...
# 2025-01-08 15:26:06,212 - BasicDaemon - Background task running...
# 2025-01-08 15:26:08,215 - BasicDaemon - Background task running...
# 2025-01-08 15:26:10,217 - BasicDaemon - Background task running...
# 2025-01-08 15:26:12,221 - BasicDaemon - Background task running...
# 2025-01-08 15:26:14,223 - BasicDaemon - Background task running...
# 2025-01-08 15:26:16,225 - BasicDaemon - Background task running...
# 2025-01-08 15:26:18,228 - BasicDaemon - Background task running...
# 2025-01-08 15:26:20,230 - BasicDaemon - Background task running...
# 2025-01-08 15:26:22,232 - BasicDaemon - Background task running...
# 2025-01-08 15:26:24,234 - BasicDaemon - Background task running...
# 2025-01-08 15:26:26,236 - BasicDaemon - Background task running...
# 2025-01-08 15:26:28,240 - BasicDaemon - Background task running...
# 2025-01-08 15:26:30,241 - BasicDaemon - Background task running...
# 2025-01-08 15:26:32,245 - BasicDaemon - Background task running...
# 2025-01-08 15:26:34,247 - BasicDaemon - Background task running...
# 2025-01-08 15:26:36,252 - BasicDaemon - Background task running...
# 2025-01-08 15:26:38,254 - BasicDaemon - Background task running...
# 2025-01-08 15:26:40,257 - BasicDaemon - Background task running...
# 2025-01-08 15:26:42,261 - BasicDaemon - Background task running...
# 2025-01-08 15:26:44,264 - BasicDaemon - Background task running...
# 2025-01-08 15:26:46,266 - BasicDaemon - Background task running...
# 2025-01-08 15:26:48,268 - BasicDaemon - Background task running...
# 2025-01-08 15:26:50,271 - BasicDaemon - Background task running...
# 2025-01-08 15:26:52,273 - BasicDaemon - Background task running...
# 2025-01-08 15:26:54,277 - BasicDaemon - Background task running...
# 2025-01-08 15:26:56,279 - BasicDaemon - Background task running...
# 2025-01-08 15:26:58,282 - BasicDaemon - Background task running...
# 2025-01-08 15:27:00,284 - BasicDaemon - Background task running...
# 2025-01-08 15:27:02,287 - BasicDaemon - Background task running...
# 2025-01-08 15:27:04,289 - BasicDaemon - Background task running...
# 2025-01-08 15:27:06,291 - BasicDaemon - Background task running...
# 2025-01-08 15:27:08,293 - BasicDaemon - Background task running...
# 2025-01-08 15:27:10,296 - BasicDaemon - Background task running...
# 2025-01-08 15:27:12,299 - BasicDaemon - Background task running...
# 2025-01-08 15:27:14,301 - BasicDaemon - Background task running...
# 2025-01-08 15:27:16,303 - BasicDaemon - Background task running...
# 2025-01-08 15:27:18,307 - BasicDaemon - Background task running...
# 2025-01-08 15:27:20,310 - BasicDaemon - Background task running...
# 2025-01-08 15:27:22,313 - BasicDaemon - Background task running...
# 2025-01-08 15:27:24,315 - BasicDaemon - Background task running...
# 2025-01-08 15:27:26,318 - BasicDaemon - Background task running...
# 2025-01-08 15:27:28,320 - BasicDaemon - Background task running...
# 2025-01-08 15:27:30,322 - BasicDaemon - Background task running...
# 2025-01-08 15:27:32,323 - BasicDaemon - Background task running...
# 2025-01-08 15:27:34,326 - BasicDaemon - Background task running...
# 2025-01-08 15:27:36,328 - BasicDaemon - Background task running...
# 2025-01-08 15:27:38,331 - BasicDaemon - Background task running...
# 2025-01-08 15:27:40,332 - BasicDaemon - Background task running...
# 2025-01-08 15:27:42,333 - BasicDaemon - Background task running...
# 2025-01-08 15:27:44,336 - BasicDaemon - Background task running...
# 2025-01-08 15:27:46,338 - BasicDaemon - Background task running...
# 2025-01-08 15:27:48,340 - BasicDaemon - Background task running...
# 2025-01-08 15:27:50,343 - BasicDaemon - Background task running...
# 2025-01-08 15:27:52,346 - BasicDaemon - Background task running...
# 2025-01-08 15:27:54,349 - BasicDaemon - Background task running...
# 2025-01-08 15:27:56,352 - BasicDaemon - Background task running...
# 2025-01-08 15:27:58,355 - BasicDaemon - Background task running...
# 2025-01-08 15:28:00,357 - BasicDaemon - Background task running...
# 2025-01-08 15:28:02,366 - BasicDaemon - Background task running...
# 2025-01-08 15:28:04,368 - BasicDaemon - Background task running...
# 2025-01-08 15:28:06,371 - BasicDaemon - Background task running...
# 2025-01-08 15:28:08,376 - BasicDaemon - Background task running...
# 2025-01-08 15:28:10,377 - BasicDaemon - Background task running...
# 2025-01-08 15:28:12,379 - BasicDaemon - Background task running...
# 2025-01-08 15:28:14,382 - BasicDaemon - Background task running...
# 2025-01-08 15:28:16,385 - BasicDaemon - Background task running...
# 2025-01-08 15:28:18,387 - BasicDaemon - Background task running...
# 2025-01-08 15:28:20,389 - BasicDaemon - Background task running...
# 2025-01-08 15:28:22,393 - BasicDaemon - Background task running...
# 2025-01-08 15:28:24,396 - BasicDaemon - Background task running...
# 2025-01-08 15:28:26,398 - BasicDaemon - Background task running...
# 2025-01-08 15:28:28,400 - BasicDaemon - Background task running...
# 2025-01-08 15:28:30,401 - BasicDaemon - Background task running...
# 2025-01-08 15:28:32,403 - BasicDaemon - Background task running...
# 2025-01-08 15:28:34,404 - BasicDaemon - Background task running...
# 2025-01-08 15:28:36,407 - BasicDaemon - Background task running...
# 2025-01-08 15:28:38,410 - BasicDaemon - Background task running...
# 2025-01-08 15:28:40,411 - BasicDaemon - Background task running...
# 2025-01-08 15:28:42,413 - BasicDaemon - Background task running...
# 2025-01-08 15:28:44,415 - BasicDaemon - Background task running...
# 2025-01-08 15:28:46,418 - BasicDaemon - Background task running...
# 2025-01-08 15:28:48,420 - BasicDaemon - Background task running...
# 2025-01-08 15:28:50,422 - BasicDaemon - Background task running...
# 2025-01-08 15:28:52,425 - BasicDaemon - Background task running...
# 2025-01-08 15:28:54,427 - BasicDaemon - Background task running...
# 2025-01-08 15:28:56,429 - BasicDaemon - Background task running...
# 2025-01-08 15:28:58,433 - BasicDaemon - Background task running...
# 2025-01-08 15:29:00,435 - BasicDaemon - Background task running...
# 2025-01-08 15:29:02,437 - BasicDaemon - Background task running...
# 2025-01-08 15:29:04,440 - BasicDaemon - Background task running...
# 2025-01-08 15:29:06,441 - BasicDaemon - Background task running...
# 2025-01-08 15:29:08,442 - BasicDaemon - Background task running...
# 2025-01-08 15:29:10,443 - BasicDaemon - Background task running...
# 2025-01-08 15:29:12,444 - BasicDaemon - Background task running...
# 2025-01-08 15:29:14,445 - BasicDaemon - Background task running...
# 2025-01-08 15:29:16,447 - BasicDaemon - Background task running...
# 2025-01-08 15:29:18,448 - BasicDaemon - Background task running...
# 2025-01-08 15:29:20,450 - BasicDaemon - Background task running...
# 2025-01-08 15:29:22,451 - BasicDaemon - Background task running...
# 2025-01-08 15:29:24,452 - BasicDaemon - Background task running...
# 2025-01-08 15:29:26,454 - BasicDaemon - Background task running...
# 2025-01-08 15:29:28,456 - BasicDaemon - Background task running...
# 2025-01-08 15:29:30,458 - BasicDaemon - Background task running...
# 2025-01-08 15:29:32,460 - BasicDaemon - Background task running...
# 2025-01-08 15:29:34,462 - BasicDaemon - Background task running...
# 2025-01-08 15:29:36,463 - BasicDaemon - Background task running...
# 2025-01-08 15:29:38,464 - BasicDaemon - Background task running...
# 2025-01-08 15:29:40,466 - BasicDaemon - Background task running...
# 2025-01-08 15:29:42,469 - BasicDaemon - Background task running...
# 2025-01-08 15:29:44,470 - BasicDaemon - Background task running...
# 2025-01-08 15:29:46,471 - BasicDaemon - Background task running...
# 2025-01-08 15:29:48,473 - BasicDaemon - Background task running...
# 2025-01-08 15:29:50,475 - BasicDaemon - Background task running...
# 2025-01-08 15:29:52,476 - BasicDaemon - Background task running...
# 2025-01-08 15:29:54,480 - BasicDaemon - Background task running...
